# %% [markdown]
# <a href="https://colab.research.google.com/github/EsraaMosaad/Spotify-Million-Playlist-Dataset-Analysis-and-Visualization/blob/main/spotifa_streamlit_dashboard_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d esraaabdelrazek/spotify-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/esraaabdelrazek/spotify-data
# License(s): other
# Downloading spotify-data.zip to /content
# 100% 319M/320M [00:16<00:00, 22.8MB/s]
# 100% 320M/320M [00:16<00:00, 19.9MB/s]

# %%
# !unzip  /content/spotify-data.zip
# Out:
# Archive:  /content/spotify-data.zip
#   inflating: playlist.parquet/._SUCCESS.crc
#   inflating: playlist.parquet/.part-00000-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00001-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00002-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00003-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00004-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00005-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00006-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00007-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00008-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00009-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00010-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00011-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00012-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00013-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00014-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00015-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00016-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00017-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00018-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00019-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00020-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00021-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00022-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00023-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00024-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00025-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00026-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00027-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00028-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00029-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00030-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00031-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00032-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00033-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00034-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00035-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00036-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00037-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00038-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00039-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00040-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00041-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00042-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00043-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00044-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00045-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00046-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00047-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00048-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parquet.crc
#   inflating: playlist.parquet/.part-00049-bb0d884f-dd7f-43f3-919c-be29803439dd-c000.snappy.parqu
4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00065-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00066-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00067-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00068-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00069-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00070-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00071-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00072-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00073-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00074-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00075-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00076-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00077-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00078-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00079-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00080-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00081-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00082-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet
#   inflating: tracks.parquet/part-00083-4ad54f69-de89-4df7-9db4-1df9636d347b-c000.snappy.parquet

# %%
# !pip install streamlit -q
#!pip install pyngrok -q
# !pip install pyspark -q
# !npm install localtunnel -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyspark (setup.py) ... done
#
# added 22 packages, and audited 23 packages in 1s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.

# %%
import streamlit as st
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, avg, dayofweek,desc
import matplotlib.pyplot as plt

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("SpotifyMillionPlaylistDataset").getOrCreate()

# Sample Data Loading (replace with your actual data loading code)
playlist = spark.read.parquet("/content/playlist.parquet")
tracks = spark.read.parquet("/content/tracks.parquet")

# %%
playlist.printSchema()
# Out:
# root
#  |-- playlist_id: long (nullable = true)
#  |-- playlist_name: string (nullable = true)
#  |-- num_tracks: long (nullable = true)
#  |-- num_albums: long (nullable = true)
#  |-- num_artists: long (nullable = true)
#  |-- num_followers: long (nullable = true)
#  |-- num_edits: long (nullable = true)
#  |-- collaborative: integer (nullable = true)
#  |-- modified_at_date: string (nullable = true)
#  |-- playlist_duration_min: double (nullable = true)
#  |-- day_of_week: integer (nullable = true)

# %%
tracks.printSchema()
# Out:
# root
#  |-- playlist_id: long (nullable = true)
#  |-- playlist_name: string (nullable = true)
#  |-- album_name: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- pos: long (nullable = true)
#  |-- track_name: string (nullable = true)
#  |-- track_duration_min: double (nullable = true)

# %%
tracks.select('track_name').distinct().show()
# Out:
# +--------------------+
# |          track_name|
# +--------------------+
# |No Promises (feat...|
# |      Arthur's Theme|
# | Parallel and Repeat|
# |10,000 Weight In ...|
# |         All In Time|
# |    Sound Of Madness|
# |              Heaven|
# |   No, No, No, Pt. 1|
# |Cheerleader - Fel...|
# |            Ride Out|
# |               Audi.|
# |I'd Do Anything F...|
# |Tonight Looks Goo...|
# |             Amazing|
# |All The Things Sh...|
# |If I Didn't Know ...|
# |            Hurt You|
# |        Sunset Lover|
# |                July|
# |       Till It Hurts|
# +--------------------+
# only showing top 20 rows

# %%
tracks.groupBy("track_name").count().orderBy(desc("count")).show()
# Out:
# +--------------------+-----+
# |          track_name|count|
# +--------------------+-----+
# |              Closer|17216|
# |                Home|12489|
# |             HUMBLE.|11675|
# |           One Dance|11256|
# |               Roses|10958|
# |     Congratulations|10583|
# |Broccoli (feat. L...|10372|
# |     Let Me Love You|10050|
# |                Ride|10026|
# |             Forever| 9554|
# |            Caroline| 9369|
# |            Location| 9028|
# |               Sorry| 8972|
# |       XO TOUR Llif3| 8840|
# |                Gold| 8793|
# |iSpy (feat. Lil Y...| 8792|
# |Bad and Boujee (f...| 8754|
# |             T-Shirt| 8578|
# |                Stay| 8534|
# |         Bounce Back| 8502|
# +--------------------+-----+
# only showing top 20 rows

# %%
# %%writefile app.py
import streamlit as st
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, when, count, row_number
from pyspark.sql.window import Window

# Initialize Spark session
spark = SparkSession.builder \
    .appName("SpotifyMillionPlaylistDataset") \
    .getOrCreate()

# Load data
playlist = spark.read.parquet("/content/playlist.parquet")
tracks = spark.read.parquet("/content/tracks.parquet")

# Streamlit application
st.title('Spotify Playlist Dashboard')

# Sidebar for user input
st.sidebar.header("User Input")

# Step 1: Top Playlists
num_playlists = st.sidebar.slider('Select number of top playlists to display:', min_value=1, max_value=35, value=10)

# Top Playlists Visualization
st.header('Top Playlists by Number of Followers')
top_playlists = playlist.groupBy("playlist_name") \
    .agg({"num_followers": "max"}) \
    .orderBy(col("max(num_followers)").desc()) \
    .limit(num_playlists) \
    .toPandas()

plt.figure(figsize=(10, 6))
sns.barplot(data=top_playlists, x="max(num_followers)", y="playlist_name", palette="viridis")
plt.title(f'Top {num_playlists} Playlists by Number of Followers')
plt.xlabel('Number of Followers')
plt.ylabel('Playlist Name')
st.pyplot(plt)

# Step 2: Average Playlist Duration
max_tracks = playlist.agg({"num_tracks": "max"}).collect()[0][0]
st.sidebar.write(f"Maximum number of tracks in any playlist: {max_tracks}")
num_bins = st.sidebar.slider('Select number of bins for track counts:', min_value=2, max_value=min(max_tracks, 20), value=5)

# Average Playlist Duration Visualization
st.header('Average Playlist Duration by Number of Tracks')
bins = [i * (max_tracks // num_bins) for i in range(num_bins + 1)]
labels = [f"{bins[i]}-{bins[i + 1]}" for i in range(num_bins)]

playlist = playlist.withColumn('track_bins',
                                when(col('num_tracks') <= bins[1], labels[0])
                                .when((col('num_tracks') > bins[1]) & (col('num_tracks') <= bins[2]), labels[1])
                                .when((col('num_tracks') > bins[2]) & (col('num_tracks') <= bins[3]), labels[2])
                                .when((col('num_tracks') > bins[3]) & (col('num_tracks') <= bins[4]), labels[3])
                                .when(col('num_tracks') > bins[4], labels[4]))

avg_duration_bins = playlist.groupBy('track_bins') \
    .agg(avg('playlist_duration_min').alias('avg_duration')) \
    .orderBy('track_bins') \
    .toPandas()

plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_duration_bins, x='track_bins', y='avg_duration', marker='o', palette='coolwarm')
plt.title('Average Playlist Duration by Number of Tracks')
plt.xlabel('Number of Tracks')
plt.ylabel('Average Duration (minutes)')
st.pyplot(plt)

# Step 3: Top Artists
num_artists = st.sidebar.slider('Select number of top artists to display:', min_value=1, max_value=35, value=10)
st.header('Top Artists')
artist_counts = (
    tracks.groupBy('artist_name')
    .agg(count('artist_name').alias('count'))
    .orderBy(col('count').desc())
    .limit(num_artists)
    .toPandas()
)

plt.figure(figsize=(10, 6))
sns.barplot(data=artist_counts, x='artist_name', y='count', palette='magma')
plt.title(f'Top {num_artists} Most Common Artists')
plt.xlabel('Artist Name')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
st.pyplot(plt)

# Step 4: Top Artists per Playlist
top_n = st.sidebar.slider('Select number of top playlists or artists to display', 5, 50, 10)
artist_per_playlist_df = tracks.groupBy("playlist_id", "artist_name").agg(count("track_name").alias("track_count"))

window_spec = Window.partitionBy("playlist_id").orderBy(col("track_count").desc())
artist_rank_df = artist_per_playlist_df.withColumn("rank", row_number().over(window_spec))
top_artists_per_playlist_df = artist_rank_df.filter(col("rank") == 1).orderBy(col("track_count").desc()).limit(top_n)

top_artists_per_playlist_pd = top_artists_per_playlist_df.toPandas()

# Streamlit Interface for Top Artists per Playlist
st.title("Top Artists per Playlist Analysis")
option = st.selectbox('Choose what you want to do:', ('Show DataFrame', 'Plot Bar Graph', 'Plot Pie Chart', 'Plot Heatmap'))

if option == 'Show DataFrame':
    st.subheader('Top Artists per Playlist DataFrame')
    st.dataframe(top_artists_per_playlist_pd)

elif option == 'Plot Bar Graph':
    st.subheader('Top Artists per Playlist - Bar Graph')
    plt.figure(figsize=(12, 6))
    sns.barplot(data=top_artists_per_playlist_pd, x='playlist_id', y='track_count', hue='artist_name', palette='crest')
    plt.xticks(rotation=90)
    plt.title(f'Top {top_n} Playlists by Track Count - Bar Graph')
    plt.xlabel('Playlist ID')
    plt.ylabel('Number of Tracks')
    st.pyplot(plt)

elif option == 'Plot Pie Chart':
    st.subheader('Top Artists per Playlist - Pie Chart')
    artist_summary = top_artists_per_playlist_pd.groupby('artist_name')['track_count'].sum().reset_index()
    plt.figure(figsize=(8, 8))
    plt.pie(artist_summary['track_count'], labels=artist_summary['artist_name'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
    plt.title(f'Top {top_n} Artists Contribution Across Playlists')
    st.pyplot(plt)

elif option == 'Plot Heatmap':
    st.subheader('Top Artists per Playlist - Heatmap')
    pivot_df = top_artists_per_playlist_pd.pivot("artist_name", "playlist_id", "track_count").fillna(0)
    plt.figure(figsize=(12, 8))
    sns.heatmap(pivot_df, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title(f'Heatmap of Top {top_n} Artists per Playlist')
    plt.xlabel('Playlist ID')
    plt.ylabel('Artist Name')
    st.pyplot(plt)

# Step 5: Artist-Specific Playlist and Track Info
artist_names = tracks.select("artist_name").distinct().toPandas()['artist_name']
selected_artist = st.sidebar.selectbox('Select an Artist:', artist_names)

st.header(f'Playlists and Tracks for {selected_artist}')
artist_playlists = tracks.filter(col("artist_name") == selected_artist) \
    .select("playlist_name", "track_name", "album_name", "track_duration_min").toPandas()

if not artist_playlists.empty:
    st.dataframe(artist_playlists)
else:
    st.write(f"No playlists found for {selected_artist}.")

# %%
# !wget -q -O - ipv4.icanhazip.com #35.194.130.91
# Out:
# 35.194.130.91

# %%
# !streamlit run app.py &>/dev/null& npx localtunnel --port 8501
# Out:
# your url is: https://strong-garlics-tap.loca.lt
